# %% [markdown]
# <a href="https://colab.research.google.com/github/amitsangani/MLProjects/blob/main/Image_Captaining_Test_HF%20Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 34.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 17.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 47.8 MB/s eta 0:00:00
# ...

# %%
import requests
from PIL import Image
from transformers import BlipProcessor, BlipForConditionalGeneration

# %%
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-large")

# %%
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-large").to("cuda")

# %%
# download the image
# img_url = 'https://storage.googleapis.com/sfr-vision-language-research/BLIP/demo.jpg' 
img_url = 'https://res.cloudinary.com/dk-find-out/image/upload/q_80,w_1920,f_auto/MA_00422215_xbxqyv.jpg'
raw_image = Image.open(requests.get(img_url, stream=True).raw).convert('RGB')

# %%
# conditional image captioning
text = "a photography of"
inputs = processor(raw_image, text, return_tensors="pt").to("cuda")
# generate the output
out = model.generate(**inputs)
print(processor.decode(out[0], skip_special_tokens=True))
# Out:
# a photography of a young girl riding a horse in a field

# %%
# unconditional image captioning
inputs = processor(raw_image, return_tensors="pt").to("cuda")

out = model.generate(**inputs)
print(processor.decode(out[0], skip_special_tokens=True))
# Out:
# there is a young girl riding a horse in a field
